# %%
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine

# %%
# Create the engine instance from local db
engine = create_engine("mysql://Gus:Gllanos900*@localhost/gll_db")

# query example
query = """
    select * from `brooklyn-one-bed`
"""

df_brooklyn = pd.read_sql(query, engine)
df_manhattan = pd.read_sql("select * from `manhattan-one-bed`", engine)
df_queens = pd.read_sql("select * from `queens-one-bed`", engine)

# %%
df_manhattan.head()
# Out:
#    MyUnknownColumn  rental_id  building_id  rent  bedrooms  bathrooms  \
# 0                3       2919     76909719  4500       1.0          1
# 1                4       2790     92953520  4795       1.0          1
# 2               15       1437     66221183  4650       1.0          1
# 3               16        404     17340497  2950       1.0          1
# 4               19       6594      9417041  4875       1.0          1
#
#    size_sqft  min_to_subway  floor  building_age_yrs  ...  has_roofdeck  \
# 0        916              2   51.0                29  ...             1
# 1        975              3    8.0                31  ...             0
# 2        915              5    5.0               106  ...             0
# 3        550             43   17.0                14  ...             1
# 4        900              1   14.0                52  ...             0
#
#    has_washer_dryer  has_doorman  has_elevator  has_dishwasher  has_patio  \
# ...

# %%
import pandas as pd
import sqlalchemy
import mysql.connector
from sqlalchemy import create_engine

sqlalchemy.__version__
# Out:
# '2.0.31'

# %% [markdown]
# #### Connect to a Database MySQL using SQL.connector

# %%
# Establish the connection
connection = mysql.connector.connect(
    user = "root",
    password = "Sugovat4741787*",
    host = "localhost",
    database = "sakila"
)
# Setup the cursor
cursor = connection.cursor()

# %%
#SQL query
query = """ SELECT * FROM film """
cursor.execute(query)

results = []
for i, data in enumerate(cursor):
    results.append(data)

# Close the cursor and connection
cursor.close()
connection.close()

# %%
len(results)
# Out:
# 1000

# %%
df  = pd.DataFrame(results)
df.columns = ["film_id",
               "title", 
               "description", 
               "release_year", 
               "language_id", 
               "original_language_id", 
               "rental_duration", 
               "rental_date", 
               "length", 
               "replacement_cost", 
               "rating", 
               "special_features",
               "last_update"]
df.head()
df.describe()
# Out:
#            film_id  release_year  language_id  rental_duration       length  \
# count  1000.000000        1000.0       1000.0      1000.000000  1000.000000
# mean    500.500000        2006.0          1.0         4.985000   115.272000
# min       1.000000        2006.0          1.0         3.000000    46.000000
# 25%     250.750000        2006.0          1.0         4.000000    80.000000
# 50%     500.500000        2006.0          1.0         5.000000   114.000000
# 75%     750.250000        2006.0          1.0         6.000000   149.250000
# max    1000.000000        2006.0          1.0         7.000000   185.000000
# std     288.819436           0.0          0.0         1.411654    40.426332
#
#                          last_update
# count                           1000
# mean   2006-02-15 05:03:42.000000512
# min              2006-02-15 05:03:42
# 25%              2006-02-15 05:03:42
# 50%              2006-02-15 05:03:42
# 75%              2006-02-15 05:03:42
# ...

# %% [markdown]
# #### Connect to a Database using SQL Alchemy

# %%
# Taken from https://docs.sqlalchemy.org/en/20/core/engines.html#mysql

engine = create_engine("mysql://Gus:Gllanos900*@localhost/sakila")

# query
query = """
    SELECT * FROM film
"""
df_sqlalchemy = pd.read_sql(query, engine)

# %%
df_sqlalchemy.head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Astounding Epistle of a Database Administrat...          2006
# 2  A Astounding Reflection of a Lumberjack And a ...          2006
# 3  A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4  A Fast-Paced Documentary of a Pastry Chef And ...          2006
#
#    language_id original_language_id  rental_duration  rental_rate  length  \
# 0            1                 None                6         0.99      86
# 1            1                 None                3         4.99      48
# 2            1                 None                7         2.99      50
# 3            1                 None                5         2.99     117
# ...

# %%
df_sqlalchemy.describe()
# Out:
#            film_id  release_year  language_id  rental_duration  rental_rate  \
# count  1000.000000        1000.0       1000.0      1000.000000  1000.000000
# mean    500.500000        2006.0          1.0         4.985000     2.980000
# min       1.000000        2006.0          1.0         3.000000     0.990000
# 25%     250.750000        2006.0          1.0         4.000000     0.990000
# 50%     500.500000        2006.0          1.0         5.000000     2.990000
# 75%     750.250000        2006.0          1.0         6.000000     4.990000
# max    1000.000000        2006.0          1.0         7.000000     4.990000
# std     288.819436           0.0          0.0         1.411654     1.646393
#
#             length  replacement_cost                    last_update
# count  1000.000000       1000.000000                           1000
# mean    115.272000         19.984000  2006-02-15 05:03:42.000000512
# min      46.000000          9.990000            2006-02-15 05:03:42
# ...

# %%
film_grouped = df_sqlalchemy.groupby(["special_features"])[["rental_duration", "rental_rate", "length", "replacement_cost"]].mean().reset_index()

film_grouped
# Out:
#                                      special_features  rental_duration  \
# 0                                   Behind the Scenes         5.271429
# 1                                        Commentaries         5.193548
# 2                      Commentaries,Behind the Scenes         5.185714
# 3                         Commentaries,Deleted Scenes         5.000000
# 4       Commentaries,Deleted Scenes,Behind the Scenes         4.742424
# 5                                      Deleted Scenes         4.901639
# 6                    Deleted Scenes,Behind the Scenes         5.140845
# 7                                            Trailers         4.555556
# 8                          Trailers,Behind the Scenes         5.319444
# 9                               Trailers,Commentaries         4.930556
# 10            Trailers,Commentaries,Behind the Scenes         5.177215
# 11               Trailers,Commentaries,Deleted Scenes         5.046875
# ...

# %%
#writing a new table in the database
df_sqlalchemy.to_sql("film_grouped", engine)
# Out:
# 1000
